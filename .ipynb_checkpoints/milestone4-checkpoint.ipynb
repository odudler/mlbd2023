# %% [markdown]
# **Notebook for Milestone 4**

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#ML imports

# %%
#Load data
users = pd.read_csv('./../data/full_calcularis_users.csv')
events = pd.read_csv('./../data/full_calcularis_events.csv')
subtasks = pd.read_csv('./../data/full_calcularis_subtasks.csv')

print('Users: {}, Events: {}, Subtasks: {}'.format(len(users), len(events), len(subtasks)))
# Out:
# Users: 64932, Events: 2185200, Subtasks: 3502884

# %% [markdown]
# **Clean up data**. This includes:
#     - *Add Items*

# %%
print(users.columns)
print(events.columns)
print(subtasks.columns)
# Out:
# Index(['user_id', 'learning_time_ms', 'logged_in_time_ms', 'language',
#        'country', 'start', 'end'],
#       dtype='object')
# Index(['event_id', 'user_id', 'mode', 'game_name', 'learning_time_ms',
#        'subtasks', 'number_range', 'start', 'end', 'skill_id', 'type'],
#       dtype='object')
# Index(['subtask_id', 'event_id', 'user_id', 'aim', 'answer', 'answerMode',
#        'availableNumbers', 'correct', 'correctAnswerObject', 'correctNumber',
#        'destination', 'distance', 'hasProperResult', 'interval', 'lowerBound',
#        'maxHeight', 'minHeight', 'mode', 'multiplier', 'number',
#        'numberRepresentations', 'numberToMultiply', 'numbers', 'operandA',
#        'operandB', 'operator', 'range', 'representation', 'representations',
#        'result', 'solution', 'solutionRepresentation', 'solveMode', 'source',
#        'speed', 'startPosition', 'subtask_finished_timestamp', 'target',
#        'timeoutInSeconds', 'timeoutInSteps', 'type', 'upperBound', 'step',
#        'orderIndependent', 'divisor', 'larger', 'smaller', 'timeout'],
#       dtype='object')

# %%
#types involve "['task' 'TRAINING_SELECTOR' 'ZOO' 'OVERVIEW' 'HELP' 'SHOP', 'ATTENTION_BOOSTER' 'GAME_START_PAUSE']"
#we are only interesting in "task" type for the wheel-spinning.
num = 2
'''

print(subtasks[subtasks['event_id'] == num]['event_id'])
print(tasks[tasks['event_id'] == num]['subtasks'].to_numpy())
tasks = tasks[tasks['game_name'] == 'Landing']
print(tasks)
subtask_series = subtasks.groupby(['event_id']).size().to_frame('num_subtasks')
print(subtask_series)
tasks.merge(subtask_series, on='event_id', how='right')
print(tasks.head(5))
print(events.skill_id.nunique())
'''
tasks = events[events.type == "task"]
print(events['skill_id'].nunique())
print(tasks['skill_id'].nunique())

for skill in tasks['skill_id'].unique():
    skill1 = tasks[tasks['skill_id'] == skill]
    #print(len(skill1))
    skill1_subtasks = subtasks[subtasks['event_id'].isin(skill1['event_id'])]

    #print(len(skill1_subtasks))

    num_subtasks = skill1_subtasks.groupby(['event_id']).size()
    print(f"Skill: {skill}, Values:{num_subtasks.unique()}")


'''
print(num_subtasks)
print(tasks)
tasks = tasks.set_index('event_id')
tasks['num_subtasks'] = subtasks.groupby(['event_id']).size()
'''
'''
tasks_more = tasks[tasks.num_subtasks > 5]
print(tasks_more[tasks_more['event_id'] == num].head(3))
'''
'''
print(tasks_more.head(1))
print(len(tasks_more))
print(len(tasks))
print(len(subtasks))
print(tasks.head(1))
print(tasks.game_name.nunique())
print(tasks.game_name.unique())
'''
# Out:
# Skill: 1.0, Values:[2]
# Skill: 3.0, Values:[1]
# Skill: 18.0, Values:[1 2]
# Skill: 19.0, Values:[1 2]
# Skill: 54.0, Values:[1]
# Skill: 43.0, Values:[2 4]
# Skill: 50.0, Values:[1 2]
# Skill: 36.0, Values:[1]
# Skill: 46.0, Values:[1]
# Skill: 109.0, Values:[1 2]
# Skill: 108.0, Values:[1 2]
# Skill: 111.0, Values:[1 2]
# Skill: 106.0, Values:[1 2]
# Skill: 105.0, Values:[1]
# Skill: 121.0, Values:[1]
# Skill: 122.0, Values:[1]
# Skill: 98.0, Values:[1]
# Skill: 99.0, Values:[1]
# Skill: 104.0, Values:[1 2]
# Skill: 103.0, Values:[2]
# Skill: 94.0, Values:[2]
# Skill: 112.0, Values:[1 2]
# Skill: 84.0, Values:[2]
# Skill: 88.0, Values:[1]
# Skill: 110.0, Values:[1 2]
# Skill: 107.0, Values:[  9   4   7   8  17  12  10  11   6  13  19   5  15   3  38  24  26  14
#   16  20  22  21  18  44  23  41  42  29  43  32  35  27  40  25  28  30
#   34 106  56  48  45  39  85  37  31  33  80  55  75  57  84  76  64  86
#   59  47 110  51  61  36  50  46  71  49  58]
# Skill: 120.0, Values:[2]
# Skill: 124.0, Values:[2]
# Skill: 90.0, Values:[1]
# Skill: 169.0, Values:[1]
# Skill: 180.0, Values:[1 2]
# Skill: 181.0, Values:[1 2]
# Skill: 177.0, Values:[1 2]
# Skill: 143.0, Values:[3]
# Skill: 175.0, Values:[1 2]
# Skill: 172.0, Values:[1]
# Skill: 146.0, Values:[3]
# Skill: 167.0, Values:[2]
# Skill: 171.0, Values:[1]
# Skill: 176.0, Values:[1]
# Skill: 178.0, Values:[ 14  12  17   8   3  10   7  11  18  13  20  15  19  16   4   9  25  21
#    5  28   6  24  35  32  72  22  31  33  30  23  26  34  75  63  42  62
#   36  38  56  29  27  46  39  52 126  53  55  47  44  40  79  43  82  58
#   94  69  88  37  70  67  59  41 149  80  48  45  50  77  74  60  65  71
#   78  57  93  68  49 129 100]
# Skill: 170.0, Values:[1 2]
# Skill: 179.0, Values:[1 2]
# Skill: 159.0, Values:[1]
# Skill: 210.0, Values:[1]
# Skill: 162.0, Values:[1]
# Skill: 166.0, Values:[2]
# Skill: 239.0, Values:[1]
# Skill: 243.0, Values:[1]
# Skill: 241.0, Values:[1]
# Skill: 0.0, Values:[ 3  2 13  1 11 10 17 16 12 14  7  4  5  8 15  6  9 18 22 26 21 20 19 27
#  25 29 23 33 24 31 45 28]
# Skill: 12.0, Values:[2]
# Skill: 30.0, Values:[2]
# Skill: 39.0, Values:[1]
# Skill: 51.0, Values:[1 2]
# Skill: 71.0, Values:[2]
# Skill: 35.0, Values:[1 2]
# Skill: 97.0, Values:[1]
# Skill: 100.0, Values:[1]
# Skill: 95.0, Values:[2]
# Skill: 133.0, Values:[1]
# Skill: 138.0, Values:[3]
# Skill: 17.0, Values:[1 2]
# Skill: 38.0, Values:[1]
# Skill: 49.0, Values:[1 2]
# Skill: 37.0, Values:[1]
# Skill: 42.0, Values:[2]
# Skill: 56.0, Values:[1]
# Skill: 47.0, Values:[10  9  6  5  4  8  3  7 11 17 12 13 14 15 35 30 18 20 19 25 22 16 27 29
#  26 44 33 23 31 32 21 28 37 39 67]
# Skill: 48.0, Values:[1 2]
# Skill: 45.0, Values:[1]
# Skill: 62.0, Values:[2 1]
# Skill: 33.0, Values:[2]
# Skill: 44.0, Values:[1]
# Skill: 22.0, Values:[1]
# Skill: 190.0, Values:[1]
# Skill: 154.0, Values:[1]
# Skill: 79.0, Values:[2]
# Skill: 7.0, Values:[1 2]
# Skill: 4.0, Values:[1]
# Skill: 11.0, Values:[2]
# Skill: 26.0, Values:[1]
# Skill: 116.0, Values:[1]
# Skill: 6.0, Values:[1]
# Skill: 14.0, Values:[1]
# Skill: 15.0, Values:[1]
# Skill: 13.0, Values:[1]
# Skill: 29.0, Values:[1]
# Skill: 142.0, Values:[3]
# Skill: 201.0, Values:[1]
# Skill: 204.0, Values:[1]
# Skill: 193.0, Values:[2]
# Skill: 24.0, Values:[1]
# Skill: 59.0, Values:[2 4]
# Skill: 27.0, Values:[1]
# Skill: 132.0, Values:[1]
# Skill: 126.0, Values:[1]
# Skill: 158.0, Values:[1]
# Skill: 58.0, Values:[1]
# Skill: 87.0, Values:[1]
# Skill: 211.0, Values:[1]
# Skill: 229.0, Values:[1]
# Skill: 148.0, Values:[3]
# Skill: 160.0, Values:[1]
# Skill: 212.0, Values:[2]
# Skill: 233.0, Values:[3]
# Skill: 216.0, Values:[1]
# Skill: 125.0, Values:[1]
# Skill: 136.0, Values:[2 1]
# Skill: 134.0, Values:[2 1]
# Skill: 61.0, Values:[1 2]
# Skill: 76.0, Values:[3]
# Skill: 10.0, Values:[2]
# Skill: 23.0, Values:[1]
# Skill: 60.0, Values:[2]
# Skill: 135.0, Values:[1]
# Skill: 118.0, Values:[1 2]
# Skill: 147.0, Values:[3]
# Skill: 73.0, Values:[3]
# Skill: 57.0, Values:[2]
# Skill: 83.0, Values:[3]
# Skill: 189.0, Values:[1]
# Skill: 75.0, Values:[2]
# Skill: 131.0, Values:[2]
# Skill: 140.0, Values:[2]
# Skill: 151.0, Values:[3]
# Skill: 156.0, Values:[2]
# Skill: 5.0, Values:[1]
# Skill: 55.0, Values:[2]
# Skill: 78.0, Values:[3]
# Skill: 91.0, Values:[1]
# Skill: 219.0, Values:[1]
# Skill: 249.0, Values:[1]
# Skill: 205.0, Values:[1 2]
# Skill: 149.0, Values:[3]
# Skill: 185.0, Values:[1]
# Skill: 139.0, Values:[1]
# Skill: 203.0, Values:[1]
# Skill: 195.0, Values:[2]
# Skill: 194.0, Values:[2]
# Skill: 230.0, Values:[2 1]
# Skill: 197.0, Values:[2]
# Skill: 82.0, Values:[2]
# Skill: 86.0, Values:[1 2]
# Skill: 21.0, Values:[1]
# Skill: 240.0, Values:[1]
# Skill: 141.0, Values:[3]
# Skill: 16.0, Values:[11  5  7  4 14  8  6 12 10  3  9 13 17 23 45 15 16 26]
# Skill: 117.0, Values:[1]
# Skill: 128.0, Values:[2 1]
# Skill: 220.0, Values:[2]
# Skill: 206.0, Values:[1]
# Skill: 225.0, Values:[1 2]
# Skill: 232.0, Values:[3]
# Skill: 227.0, Values:[1]
# Skill: 66.0, Values:[1]
# Skill: 238.0, Values:[1]
# Skill: 81.0, Values:[1]
# Skill: 28.0, Values:[2]
# Skill: 119.0, Values:[2]
# Skill: 70.0, Values:[1]
# Skill: 68.0, Values:[1]
# Skill: 236.0, Values:[3]
# Skill: 244.0, Values:[1]
# Skill: 214.0, Values:[2]
# Skill: 228.0, Values:[1]
# Skill: 163.0, Values:[1]
# Skill: 221.0, Values:[2]
# Skill: 186.0, Values:[1]
# Skill: 208.0, Values:[1]
# Skill: 198.0, Values:[2]
# Skill: 235.0, Values:[3]
# Skill: 77.0, Values:[3]
# Skill: 202.0, Values:[1]
# Skill: 155.0, Values:[3]
# Skill: 246.0, Values:[1]
# Skill: 209.0, Values:[1]
# Skill: 114.0, Values:[2]
# Skill: 127.0, Values:[2 1]
# Skill: 130.0, Values:[2]
# Skill: 224.0, Values:[1]
# Skill: 129.0, Values:[1]
# Skill: 250.0, Values:[1]
# Skill: 215.0, Values:[2]
# Skill: 53.0, Values:[2]
# Skill: 199.0, Values:[2]
# Skill: 74.0, Values:[1]
# Skill: 150.0, Values:[3]
# Skill: 234.0, Values:[3]
# Skill: 200.0, Values:[2]
# Skill: 183.0, Values:[2]
# Skill: 153.0, Values:[1]
# Skill: 207.0, Values:[1]
# Skill: 191.0, Values:[2]
# Skill: 217.0, Values:[1]
# Skill: 196.0, Values:[2]
# Skill: 247.0, Values:[1]
# Skill: 69.0, Values:[1]
# Skill: 248.0, Values:[1]
# Skill: 115.0, Values:[2]
# Skill: 213.0, Values:[2]
# Skill: 242.0, Values:[1]
# Skill: 218.0, Values:[1]
# Skill: 222.0, Values:[2]
# Skill: 144.0, Values:[3]
# Skill: 123.0, Values:[2]
# Skill: 192.0, Values:[2]
# Skill: 188.0, Values:[2]
# Skill: 187.0, Values:[2]
# Skill: 65.0, Values:[2 1]
# Skill: 226.0, Values:[1]
# Skill: 67.0, Values:[2]
# Skill: 184.0, Values:[2]
# Skill: 223.0, Values:[2]
# '\nprint(tasks_more.head(1))\nprint(len(tasks_more))\nprint(len(tasks))\nprint(len(subtasks))\nprint(tasks.head(1))\nprint(tasks.game_name.nunique())\nprint(tasks.game_name.unique())\n'

# %% [markdown]
# Calcularis has 29 different games. The question is, if each game is a different "skill" or if some are the same skill? We would need to categorize the games into the respective skills, but the problem is that we can only see 10 games in the demo version.

# %%
#Test how many tasks students solved in general of which type (to find proper threshold

#find out which games get played the most often:
#games = tasks[['user_id', 'game_name']].groupby(['game_name']).size().sort_values(ascending=False)
#top_10 = games.head(10)
#We work only on the 10 most played games (still 94,5% of the data)
top_10 = ['Landing', 'Conversion', 'Comparison', 'Distance', 'Calculator',
          'Estimation on Number Line','Order', 'Subitizing', 'Secret Number', 'Estimation']

tasks = tasks[tasks['game_name'].isin(top_10)] #94.5% of the data

#plot distribution of game_types played by users
fig, axs = plt.subplots(5,2,figsize=(10,16))
for i, game_type in enumerate(top_10):
    t = tasks[tasks['game_name'] == game_type][['user_id', 'game_name']]
    print(len(t))
    t = t.groupby(['user_id']).count()
    t.columns = ['count']
    sns.histplot(data=t, bins = 100, ax=axs[i // 2, i % 2]).set(title=game_type)
    
#A lot of students have less then 10 games played for a certain game_type.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       1 #Test how many tasks students solved in general of which type (to find proper threshold
#       2
#       3 #find out which games get played the most often:
#       4 #games = tasks[['user_id', 'game_name']].groupby(['game_name']).size().sort_values(ascending=False)
#       5 #top_10 = games.head(10)
#       6 #We work only on the 10 most played games (still 94,5% of the data)
#       7 top_10 = ['Landing', 'Conversion', 'Comparison', 'Distance', 'Calculator',
#       8           'Estimation on Number Line','Order', 'Subitizing', 'Secret Number', 'Estimation']
# ---> 10 tasks = tasks[tasks['game_name'].isin(top_10)] #94.5% of the data
#      12 #plot distribution of game_types played by users
#      13 fig, axs = plt.subplots(5,2,figsize=(10,16))
#
# NameError: name 'tasks' is not defined

# %%
#Attempt to create a timeseries dataframe for just one skill yet (Landing)
skill = 'Landing'
THRES_HOLD = 10
landing = tasks[tasks['game_name'] == skill]
#filter out all students who have less then THRES_HOLD "Practice Opportunities"
print("Total instances of Landing event: " +  str(len(landing)))
users_count = landing[['user_id', 'game_name']].groupby(['user_id']).count()
users_count.columns = ['count']
print("Users who performed the landing event:" + str(len(users_count)))
users_ten = users_count[users_count['count'] >= THRES_HOLD].index.to_numpy()

#print(users_ten)
print("Users who performed at least 10 landing events:" + str(len(users_ten))) #about 1/2 of users
landing_ten = landing[landing['user_id'].isin(users_ten)]
# Out:
# Total instances of Landing event: 676878
# Users who performed the landing event:49397
# Users who performed at least 10 landing events:24804

# %%
#filtering not really necessary for initial timeseries creation.
#dataframe "landing": includes all the instances of events of the type "Landing" from all students
#for ease of coding, initially only take some relevant columns:
#also only consider first 100 users, as otherwise it takes too long

print(landing.columns)

landing.head(2)
relevant = landing[['user_id', 'game_name', 'start','event_id']]
relevant = relevant[relevant['user_id'] <= 100]
print(len(landing))
print(len(relevant))

for index, row in relevant.iterrows():
    user = row['user_id']
    start = row['start']
    event = row['event_id']
    game_name = row['game_name']
    #Set the "practice opportunity" field
    prior_events = relevant[(relevant['user_id'] == user) & (relevant['start'] < start)]
    relevant.loc[index,'PO'] = int(len(prior_events))
    #Set the "correct" field to 1 if ALL subtasks were solved correctly!
    event_subtasks = subtasks[subtasks['event_id'] == event]['correct']
    relevant.loc[index, 'correct'] = 1 if all(v == 1 for v in event_subtasks.values) else 0
    #Set the "correct response count" field
    relevant.loc[index, 'CRC'] = relevant[(relevant['user_id'] == user) & (relevant['start'] < start)]['correct'].sum()
    
for index, row in relevant.iterrows():
    #Set the "Correct response in a row count" field
    c = row['correct']
    if row['PO'] == 0:
        relevant.loc[index,'CRRC'] = c
    else:
        if c == 1:
            prior_val = relevant[(relevant['user_id'] == row['user_id']) & \
                            (relevant['game_name'] == row['game_name']) & \
                            (relevant['PO'] == row['PO'] - 1)].head()['CRRC'].values[0]
            relevant.loc[index,'CRRC'] = 1 + prior_val
        else:
            relevant.loc[index,'CRRC'] = 0
    
    
    
relevant = relevant.reset_index()
relevant.head(10)
# Out:
# Index(['event_id', 'user_id', 'mode', 'game_name', 'learning_time_ms',
#        'subtasks', 'number_range', 'start', 'end', 'skill_id', 'type',
#        'num_subtasks'],
#       dtype='object')
# 676878
# 855
#    index  user_id game_name                     start  event_id   PO  correct  \
# 0      2        2   Landing  2020-08-24T07:02:59.855Z         4  0.0      1.0
# 1      3        2   Landing  2020-08-26T06:47:21.504Z         5  1.0      1.0
# 2      6        2   Landing  2020-08-31T06:52:10.097Z         9  2.0      1.0
# 3      9        2   Landing  2020-09-07T06:43:35.101Z        12  3.0      1.0
# 4     10        2   Landing  2020-09-09T07:08:21.657Z        13  4.0      1.0
# 5     11        2   Landing  2020-09-11T07:19:13.651Z        14  5.0      0.0
# 6     12        2   Landing  2020-09-14T07:15:42.563Z        15  6.0      1.0
# 7     15        2   Landing  2020-09-17T07:29:01.812Z        21  7.0      0.0
# 8     17        2   Landing  2020-09-21T06:43:51.387Z        23  8.0      0.0
# 9     21        2   Landing  2020-09-25T06:54:01.107Z        27  9.0      0.0
#
#    CRC  CRRC
# 0  0.0   1.0
# 1  1.0   2.0
# 2  2.0   3.0
# 3  3.0   4.0
# 4  4.0   5.0
# 5  5.0   0.0
# 6  5.0   1.0
# 7  6.0   0.0
# 8  6.0   0.0
# 9  6.0   0.0

# %% [markdown]
# **Create table with selected features**:
# - *per student/skill pair*:
#     - Correct response count
#     - Correct response in a row count
#     - Expected mean response time z-score
#     - <s> Prior problem count with hint request
#     - <s> prior problem count with at least 5 hint request
# - *per student*:
#     - Prior problem count fast correct
#     - Prior problem count normal correct
#     - Prior problem count slow correct
#     - Prior problem count fast incorrect
#     - Prior problem count normal incorrect
#     - Prior problem count slow incorrect
#     - <s> Prior problem count with hint request in a row
#     - <s> Prior problem count with at least 5 hint requests in a row
# - *per student/skill pair (I think?)*
#     - Prior problem count
#     - Skill ID

# %% [markdown]
# **Add "wheel-spinning" column to DataFrame applying our definition of wheel-spinning:**
# - *Three in a row*
# - *Based on BLK*
# - *other?*

# %% [markdown]
# **Predict wheelspinning using e.g. Logistic Regression, compare result to labels**
